# %% [markdown]
# <table>
#  <td><a rel="license" href="http://creativecommons.org/licenses/by/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by/4.0/88x31.png" /></a></td>
#  <td>Text provided under a Creative Commons Attribution 4.0 International License. <br/>All code is made available under the FSF-approved MIT license. &copy; Joanna Klukowska</td>
# </table>

# %%
from __future__ import print_function

import numpy
import matplotlib.pyplot as plt
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import math
import numpy as np
import time

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>

# %%
HTML('''<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# <br><br><br>
#
# # Teaching with Jupyter Notebooks
# ##  Five Tools in One
#
# <br><br><br>
# Joanna Klukowska
#
# New York University, Courant Institute of Mathematical Sciences

# %% [markdown]
# ## Multiple Tools in a Single Notebook
#
# 1. notes for students
# 2. slides for display during class time
# 3. code wrting
# 5. interactive features
# 4. graphics generation and display

# %% [markdown]
# ## Lecture Notes
#
#
#
# - access
# - execute
# - interact
# - modify

# %% [markdown]
# ## Slides for Class Presentation
#
#
# - easy formatting using markdown <br>
#   ex.
#         ## Slide title
#
#
#         - list item 1
#
#         - list item with equation <br>
#           ex. `$f(x) = \sum_{i=1}^{x}i^2 $`
#
#
# <br>
#
# - mathematical notation using Latex,
#   ex.  $f(x) = \sum_{i=1}^{x}i^2 $ <br><br>
#
# - include graphics using basic HTML <img src="https://as.nyu.edu/content/dam/nyu-as/communications/images/VisualIdentityDownloads/AS/logos/arts_science_short_color.png" width="300px">

# %% [markdown]
# ## Code
#
# - editing and execution in a single environment
# - run the code in the slides

# %%
name = input("What's your name? ")
print("It is great to meet you " + name )
# Out:
# What's your name? Joanna
# It is great to meet you Joanna

# %%
for num in [2,3,5,7,11,13,17,19] :
    print ( format(num, '3d'), format(num**2, '4d'),format(num**3, '4d'), sep = "\t")
# Out:
#   2	   4	   8
#   3	   9	  27
#   5	  25	 125
#   7	  49	 343
#  11	 121	1331
#  13	 169	2197
#  17	 289	4913
#  19	 361	6859

# %% [markdown]
# ## Credit Card Payments - Interactive Mode

# %%
HTML('''<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
# %matplotlib inline
def credit_card_payment(interest, payment ) :    
    bill = 200.00
    total = 0.0
    balance = [bill]
    ind = 1
    while balance[ind-1] > 0 and ind < 120 :
        if balance[ind-1] >= payment:
            balance.append( (balance[ind-1] - payment) * (1+interest) ) 
            total += payment 
        else : 
            balance.append( 0 )
            total  += balance[ind-1]
        ind += 1 
    balance.append(0)   
    months = np.linspace(0, len(balance)-1, len(balance) )
    
    plt.figure(figsize=(14,6))
    plt.plot(months, balance, 'ro')
    plt.xlabel('Months/Payments')        # add title to the x-axis
    plt.ylabel('Remaining Balance')      # add title to the y-axis 
    plt.show()
    print("Total paid: $", format(total,',.2f'), ".", sep="")
    
interact(credit_card_payment, interest=(0.0,0.1,0.01), payment=(0.00, 100.00, 5) )
# Out:
# interactive(children=(FloatSlider(value=0.05, description='interest', max=0.1, step=0.01), FloatSlider(value=5…
# <function __main__.credit_card_payment(interest, payment)>

# %% [markdown]
# # Art of [Hamid Naderi Yeganeh](https://www.sciencefriday.com/articles/math-is-beautiful/)
#
# Can math produce art?

# %%
# %matplotlib notebook
fig, ax = plt.subplots(figsize=(10,8))
ax.set_xlim(-1.75,1.75)
ax.set_ylim(-1,1)
ax.set_aspect(1)
plt.xticks([])
plt.yticks([])
for i in range (1000) : 
    x1 = -1 * math.sin(4 * math.pi * i/1000)
    y1 = -1 * math.cos(2 * math.pi * i/1000)
    x2 = (-1/2)*math.sin(8 * math.pi * i/1000)
    y2 = (-1/2)*math.cos(4 * math.pi * i/1000)
    d = np.array([[x1,y1], [x2,y2]]) 
    plt.plot(d[:,0],d[:,1], color='black', linewidth=0.1)
fig.canvas.draw()
# Out:
# <img src="data:image/png;base64,..." width="720">

# %%
# %matplotlib inline
fig, ax = plt.subplots(figsize=(10,10))
ax.set_xlim(-1.5, 1.5)
ax.set_ylim(-1.5,1.5)
ax.set_aspect(1)
plt.xticks([])
plt.yticks([])
count = 10000

for k in range (10000) : 
    x = math.cos(14 * math.pi * k / count) * (1 - 3/4 * (math.cos(20*math.pi*k/count)**2))
    y = math.sin(14 * math.pi * k / count) * (1 - 3/4 * (math.cos(24*math.pi*k/count)**2))
    r = 1/200 + 1/10 * (math.sin(54*math.pi*k/count)**6)
    
    circle = plt.Circle((x, y), r, color='black', fill=False,linewidth=0.1)
    ax.add_artist(circle)

   
plt.show()

# %%
# %matplotlib notebook
fig, ax = plt.subplots(figsize=(10,4))
ax.set_xlim(-1.75,1.75)
ax.set_ylim(-.75,.5)
ax.set_aspect(1)
plt.xticks([])
plt.yticks([])
for i in range (500) : 
    x1 = 3/2 * (math.sin(2 * math.pi * i/500 + math.pi / 3))**7
    y1 = 1/4 * (math.cos(6 * math.pi * i/500) )**2
    x2 = 1/5 * math.sin(6 * math.pi * i/500 + math.pi/5)
    y2 = (-2/3)*(math.sin(2 * math.pi * i/500 - math.pi/3 ) )**2
    d = np.array([[x1,y1], [x2,y2]]) 
    plt.plot(d[:,0],d[:,1], color='black', linewidth=0.1)
    fig.canvas.draw()

# %matplotlib inline
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="720">

# %%
HTML('''<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>
